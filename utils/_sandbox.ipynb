# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot(range(100))

# %%
# %matplotlib notebook
line = plt.plot(range(100))
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib inline
line[0].figure
# Out:
# <img src="data:image/png;base64,...">
